# %% [markdown]
# SVMs are used in applications like handwriting recognition, intrusion detection, face detection, email classification, gene classification, and in web pages. This is one of the reasons we use SVMs in machine learning. It can handle both classification and regression on linear and non-linear data.

# %% [markdown]
# The objective of the support vector machine algorithm is to find a hyperplane in an N-dimensional space(N — the number of features) that distinctly classifies the data points. To separate the two classes of data points, there are many possible hyperplanes that could be chosen

# %% [markdown]
# https://www.google.com/search?q=where+we+use+support+vector+machine&client=firefox-b-d&sxsrf=ALiCzsYEm3gyd_9sNq8tXTApCzPqWLASqA:1659518084837&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjSusfPqqr5AhWm7TgGHYFvCqsQ_AUoA3oECAEQBQ&biw=1366&bih=620&dpr=1#imgrc=pCj4qS6NoIDTjM

# %% [markdown]
# The support vector machine is a model used for both classification and regression problems though it is mostly used to solve classification problems.

# %% [markdown]
# <font color=red>    LOGISTIC REGRESSION PROVIDES A SCALE FORM 0 TO 1 AND IT DIFFERNTIATES BASIS OF IT , BUT IT IS NOT IN CASE OF SUPPORT VECTOR MACHINES , IN CASE OF SVM IT FORMS A SEPARATION OF VALUES , IF THE DATA VISUALIZATION  SHOWS A CLEAR SEPARATION IT GIVES US A CONFIDENCE OF USING SVM ,IF THE SEPARATION IS NOT STARIGHTAWAY WE CAN USE Z TRANSFORMATION </font>

# %%
import pandas as pd
import matplotlib.pyplot as plt
iris=pd.read_csv('https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv')
iris1=iris[:50]
iris2=iris[50:100]
iris3=iris[100:]
iris.head(3)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa

# %% [markdown]
# # Visualization

# %%
plt.scatter(iris1['sepal.length'],iris1['sepal.width'])
plt.scatter(iris2['sepal.length'],iris2['sepal.width'],color='crimson')
# this is showing a clear separation , so it gives us a confidence that we can use SVM

# %%
# this is showing a clear separation , so it gives us a confidence that we can use SVM
plt.scatter(iris1['petal.length'],iris1['petal.width'])
plt.scatter(iris2['petal.length'],iris2['petal.width'],color='crimson')
plt.scatter(iris3['petal.length'],iris3['petal.width'],color='green')

# %% [markdown]
# # Modelling

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
x=iris.drop(['variety'],axis=1)
y=iris.variety
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2)
model=SVC(C=1) # c means regularization , here it is low regularization, we can also try gamma
model.fit(X_train,y_train)
model.predict(X_test)
model.score(X_test,y_test)
# Out:
# 0.9666666666666667

# %%
import seaborn as sns
sns.pairplot(iris,hue='variety',diag_kind="hist")
